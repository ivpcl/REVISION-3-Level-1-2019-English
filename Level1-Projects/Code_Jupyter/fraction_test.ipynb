# %%
import os
import sys
from AOLME_Fraction_v2 import FrV
from IPython.display import HTML

# %%
frac = FrV()
frac.insertImage('Bob.jpg')

frac1 = frac.AddFrac(6,10,comment="6/10")
frac2 = frac.AddFrac(1,5,comment="1/5")
frac3 = frac.AddFrac(2,10,comment="2/10")

frac_1_2 = frac.combine_two_fracs(frac2, frac3, comment="Multiple frac2 and frac3")
frac.AddMult(2,10,3,comment='3*2/10 is 6/10')

my_string ="My name is Wenjing"
frac.addTextFrame (text=my_string)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
video_name = "my_video.mp4"
my_fps = 5
HTML(frac.CreateVideo(video_name, fps=my_fps))
# Out:
# [ WARN:0@1.163] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (2180) open OpenCV | GStreamer warning: cannot link elements
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# 2023-01-04 12:02:35.121 python[83266:3093418] WARNING: -finishWriting should not be called on the main thread.
#              <video width="320" height="240" controls>
#              <source src="my_video.mp4" type="video/mp4">
#              </video>
