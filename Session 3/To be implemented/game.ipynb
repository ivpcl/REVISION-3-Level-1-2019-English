# %% [markdown]
# Load local modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 3/To be implemented/scene_manager.py" .
# !cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 3/To be implemented/sprites.py" .
# !cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 3/To be implemented/parts.py" .
# !cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 3/To be implemented/sAOLME.py" .
# !cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 3/To be implemented/AOLME_game.py" .

# %% [markdown]
# Run python script

# %%
# Study the code below and modify when done.
from AOLME_game import *

# Modify the commands below
scene.block_move_sprite_down('aolme')
scene.block_move_sprite_right('aolme')
scene.block_move_sprite_up('aolme')
scene.block_move_sprite_left('aolme')

# Display your solution
show = scene.play_game()
