# %% [markdown]
# Load local modules

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp "/content/drive/My Drive/Colab Notebooks/REVISION 3-Level 1-2019-English/REVISION 3-Level 1-2019-English/Session 5/To be implemented/AOLME.py" .

# %% [markdown]
# Run python script

# %%
from AOLME import *

matrix = [["1"]*10 for i in range(10)]

'''
******************************************************************************
Put your code below this line
******************************************************************************
'''
for row in range(10):
    matrix[row][4] = "0"

for col in range(10):
    matrix[0][col] = "0"

'''
******************************************************************************
Put your code above this line
******************************************************************************
'''
im_show(matrix)
# Out:
# 10 10
